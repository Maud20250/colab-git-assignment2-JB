# %%
# !git config --global user.name "Maud20250"
# !git config --global user.email "jean.billa@students.williscollege.com"

# %%
# !git --version
# !git config --list
# Out:
# git version 2.34.1
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# user.name=Maud20250
# user.email=jean.billa@students.williscollege.com

# %%
# !git clone https://github.com/Maud20250/colab-git-assignment2-JB.git
# Out:
# Cloning into 'colab-git-assignment2-JB'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls colab-git-assignment2-JB
# Out:
# README.md

# %%
# !ls -la colab-git-assignment2-JB
# Out:
# total 16
# drwxr-xr-x 3 root root 4096 Jun 21 04:40 .
# drwxr-xr-x 1 root root 4096 Jun 21 04:40 ..
# drwxr-xr-x 8 root root 4096 Jun 21 04:40 .git
# -rw-r--r-- 1 root root   73 Jun 21 04:40 README.md

# %% [markdown]
# # Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12
